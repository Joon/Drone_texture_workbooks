# %%
from PIL import Image

example_file = 'C:/Work/LYIT/Dissertation/CNNTest/hires/test-large/DJI_0099200.jpg.out'
file = Image.open(example_file)

# %%
file.getcolors()
# Out:
# [(185, 0), (7368338, 1), (78014, 2), (403180, 3), (444683, 4)]

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
imshow(np.asarray(file))

# %%
smexample_file = 'C:/Work/LYIT/Dissertation/CNNTest/hires/test-small/DJI_0099200.jpg.out'
sm_file = Image.open(smexample_file)
# %matplotlib inline
imshow(np.asarray(sm_file))

# %%
medexample_file = 'C:/Work/LYIT/Dissertation/CNNTest/hires/test-med/DJI_0099200.jpg.out'
med_file = Image.open(medexample_file)
# %matplotlib inline
imshow(np.asarray(med_file))
